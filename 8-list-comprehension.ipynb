# %% [markdown]
# <h1> List Comprehension </h1>
# <a id="LComprehension"></a>
#
# <p>When working with a list and we want to apply a build-in or specific function to each item in the list, an ordinary <b>for</b> loop can be used.
# <br> However, there is a better way to accomplish the same task by using <b>list comprehension</b>. If we have <b><i>list1</i></b> then the following statment will create new list <b><i>list2</i></b> and places <b><i>f(item)</i></b> into the list for each <b><i>item</i></b> of the <b><i>list1</i></b>, where <b><i>f</i></b> is either a Python build-in or user-defined function.
# <br>
# <br> <b> list2 = [ f(x)  for  x  in  list1 ] </b>
# </p>

# %%
# Create new list by modifying existing list through build-in function
list1 = ['2', '5', '6', '8', '9']
list2 = [int(x) for x in list1]
list2

# %% [markdown]
# <p> The <b>for</b> clause in a list comprehension can optionally be folloed by an <b>if</b> clause. </p>

# %%
# Create new list by modifying existing list through build-in function and if clasuse 
list1 = ['2', '5', '6', '8', '9']
list2 = [int(x)**2 for x in list1 if int(x) % 2 == 1]  # filter for only odd numbers 
list2

# %% [markdown]
# <p> The is nothing special about variable <b>x</b>, we can use any other name as variable insted
# <br>[g(num) for num in list1 if int(num) % 2 == 1].
# <br>
# <br>List comprehension can be applied to objects ither than list, such as string, tuples, and arithmetic progressions generated by <b>range</b> functions.
# </p>

# %%
# Application of list comprehenssion to string, tuples, and ranges
print([ord(x) for x in "abc"])
print([x ** 0.5 for x in (4, -1, 9) if x > 0])
print([x ** 2 for x in range(3)])

# %% [markdown]
# ## Practice
# Use the following list1 for the practice <br>
# list1 = ['democrat', 'republican', 'country', 'capital', 'constitution', 'independence']

# %% [markdown]
# <p> Q1) Determine the value of <b>list2</b>
# <br>
# <br> list2 = [len(word) for word in list1]
# </p>

# %% [markdown]
# <p> Q2) Determine the value of <b>list2</b>
# <br>
# <br> list2 = [word.capitalize() for word in list1]
# </p>

# %% [markdown]
# <p> Q3) Determine the value of <b>list2</b>
# <br>
# <br> list2 = [word.upper() for word in list1 if len(word) < 8]
# </p>

# %% [markdown]
# <p> Q4) Determine the value of <b>list2</b>
# <br>
# <br> list2 = [word.title() for word in list1 if len(word) % 2 == 0 < 8]
# </p>

# %% [markdown]
# <p> Q5) Determine the value of <b>list2</b>
# <br>
# <br> list2 = [word[0:3].upper() for word in list1 if len(word)%2 == 1 < 8]
# </p>
